# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Blight_Violations_DAH.csv")
# Out:
# C:\Users\Neil\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#            X          Y  OBJECTID  ticket_id ticket_number  \
# 0 -83.266439  42.382235      1001     444485   18041266DAH
# 1 -83.241951  42.426627      1002     453596   19022244DAH
# 2 -83.107540  42.421249      1003     437214   18034679DAH
# 3 -82.945043  42.407769      1004     429920   18027180DAH
# 4 -82.945043  42.407769      1005     429920   18027180DAH
#
#                                       agency_name    inspector_name  \
# 0  Buildings, Safety Engineering & Env Department     Eric Kuuttila
# 1  Buildings, Safety Engineering & Env Department    Trish Williams
# 2  Buildings, Safety Engineering & Env Department  Michael Madrigal
# 3  Buildings, Safety Engineering & Env Department    Trish Williams
# 4  Buildings, Safety Engineering & Env Department    Trish Williams
#
#          violator_name  violation_street_number violation_street_name  \
# 0  12875 W PARKWAY LLC                    12875      WEST PARKWAY
# ...

# %%
import pandas as pd
import numpy as np

train_data = pd.read_csv("train.csv", encoding = 'ISO-8859-1',low_memory=False)
test_data = pd.read_csv("readonly/test.csv", encoding = 'ISO-8859-1',low_memory=False)
address = pd.read_csv("readonly/addresses.csv", encoding = 'ISO-8859-1',low_memory=False)
latlong = pd.read_csv("readonly/latlons.csv", encoding = 'ISO-8859-1',low_memory=False)

# %%
X_train = train_data.iloc[:,0:33]
y_train = train_data.iloc[:,-1]

# %%
train_data['compliance_detail'].value_counts()

# %%
cc = train_data[train_data['compliance'] == 1]

# %%
cc['compliance_detail'].value_counts()

# %%
train_data['compliance'].value_counts()

# %%
test_data.head()
